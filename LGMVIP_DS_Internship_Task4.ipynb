# %%
#LGMVIP-DS-Internship_Task-4-Ali Amir Khawaja

#Libraries Used is this task
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

image_path = '/content/img.png'
image = cv2.imread(image_path)

desired_width = 500
desired_height = 300

resized_image = cv2.resize(image, (desired_width, desired_height))

cv2_imshow(resized_image)
# Out:
# <PIL.Image.Image image mode=RGB size=500x300 at 0x7FF2D8CC7D60>

# %%
#converting image to greyscale using .cv2Color function
gray_image = cv2.cvtColor(resized_image, cv2.COLOR_BGR2GRAY)

cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=500x300 at 0x7FF2D8CC7E50>

# %%
# Invert the image
inverted_image = 255 - gray_image

# Display the inverted image
cv2_imshow(inverted_image)
# Out:
# <PIL.Image.Image image mode=L size=500x300 at 0x7FF2D8CC7E50>

# %%
# Apply blur effect to the image
blurred_image = cv2.GaussianBlur(inverted_image, (21, 21), 0)

# Display the blurred image
cv2_imshow(blurred_image)
# Out:
# <PIL.Image.Image image mode=L size=500x300 at 0x7FF2D8B805E0>

# %%
# Divide the gray image by the blurred image element-wise
pencil_sketch = cv2.divide(gray_image, blurred_image, scale=256.0)

# Display the resulting pencil image
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=500x300 at 0x7FF2D8B82F50>
